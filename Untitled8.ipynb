# %%
# %run ./conf.py

# %%
# %run ./price_calculation.py
# Out:
# Подгружаем котировки и курсы
# C:\Users\150ho\price_calculation.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_rubber = df_rubber.append(df1, ignore_index=True)
# C:\Users\150ho\price_calculation.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_rubber = df_rubber.append(df1, ignore_index=True)
# C:\Users\150ho\price_calculation.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_rubber = df_rubber.append(df1, ignore_index=True)
# C:\Users\150ho\price_calculation.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_rubber = df_rubber.append(df1, ignore_index=True)
# ...

# %%
# %run ./price_calculation_mod.py
# Out:
# hello
# Подгружаем котировки и курсы
# C:\Users\150ho\price_calculation_mod.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_rubber = df_rubber.append(df1, ignore_index=True)
# C:\Users\150ho\price_calculation_mod.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_rubber = df_rubber.append(df1, ignore_index=True)
# C:\Users\150ho\price_calculation_mod.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_rubber = df_rubber.append(df1, ignore_index=True)
# C:\Users\150ho\price_calculation_mod.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_rubber = df_rubber.append(df1, ignore_index=True)
# ...

# %%
from price_calculation_mod import calculate_prices

# %%
calculate_prices()
# Out:
# hello
# Подгружаем котировки и курсы
# C:\Users\150ho\price_calculation_mod.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_rubber = df_rubber.append(df1, ignore_index=True)
# C:\Users\150ho\price_calculation_mod.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_rubber = df_rubber.append(df1, ignore_index=True)
# C:\Users\150ho\price_calculation_mod.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_rubber = df_rubber.append(df1, ignore_index=True)
# C:\Users\150ho\price_calculation_mod.py:27: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_rubber = df_rubber.append(df1, ignore_index=True)
# ...

# %%
ls
# Out:
#  Том в устройстве C имеет метку Windows
#  Серийный номер тома: DCD7-40E3
#
#  Содержимое папки C:\Users\150ho
#
# 10.07.2022  23:02    <DIR>          .
# 10.07.2022  23:02    <DIR>          ..
# 10.07.2022  23:02    <DIR>          .conda
# 20.05.2022  22:46                25 .condarc
# 20.05.2022  22:45    <DIR>          .continuum
# 24.05.2022  20:50    <DIR>          .eclipse
# 09.07.2022  22:20    <DIR>          .ipynb_checkpoints
# 21.05.2022  00:19    <DIR>          .ipython
# 09.07.2022  20:10    <DIR>          .jupyter
# 21.05.2022  00:27    <DIR>          .matplotlib
# 23.06.2022  19:41    <DIR>          .ms-ad
# 09.07.2022  22:14                 1 __init__.py
# 10.07.2022  23:01    <DIR>          __pycache__
# 09.07.2022  22:16             1 078 _viminfo
# 20.05.2022  13:47    <DIR>          3D Objects
# 04.07.2022  21:10    <DIR>          anaconda3
# 09.07.2022  20:23    <DIR>          clients_wbp_prices
# 09.07.2022  20:10             1 046 conf.py
# ...
